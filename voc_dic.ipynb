# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
url = 'https://www.ver-taal.com/vocabulario.htm'

# %%
# accessing the html content form webpage
response = requests.get(url)

# parsing the html content
soup = BeautifulSoup(response.content, 'html')

# get the title 
title = soup.title.text + '.csv'

title
# Out:
# 'Ejercicios de vocabulario.csv'

# %%
# extract the element from list that we will include it as headers

headers_contenaire =[] # here we where store our hearders

# this tag contains the list of elements
headers = soup.select_one('ul', attri={'class':'nolist'})

type(headers)
# Out:
# bs4.element.Tag

# %%
# Iterate all row in list in html
for row in headers:
    
    # romove the element which
    if row != '\n':
    
        headers_contenaire.append(row.text) # add each row to the list

print(headers_contenaire)
# Out:
# ['La casa\nEl cuerpo y la salud\nLos animales\nLa comida\nLa ropa\nLa familia\nEl transporte\nEl ocio\nEl trabajo\nEl mundo vegetal\nEl Mundo\nLa ciudad\nLos colores, los números y las formas\n']

# %%
# Remove Empty, underline elements
headers_contenaire = list(filter(None, headers_contenaire[0].split('\n')))

headers_contenaire
# Out:
# ['La casa',
#  'El cuerpo y la salud',
#  'Los animales',
#  'La comida',
#  'La ropa',
#  'La familia',
#  'El transporte',
#  'El ocio',
#  'El trabajo',
#  'El mundo vegetal',
#  'El Mundo',
#  'La ciudad',
#  'Los colores, los números y las formas']

# %%
# Now after we obtain the headers we will dive deeper into each element using it href to get it data

a = headers.find_all('a')

list_ = []
for href in a:
    array = []

    # Extract all links of rows
    url = 'https://www.ver-taal.com/' + href.get('href')
    
    print(url)

    # parsing each url using BeautifulSoup model
    url = requests.get(url)


    soup_2 = BeautifulSoup(url.content, 'html')

    table = soup_2.table

 
    for row in table.find_all('tr'):
        
        row = row.find('a')

         # add each collection to an array
        if row is not None:
            
            # this pattern of elinated elements
            pattern = r'\W\d\W'

            pattern2 = r' \d'
            
            # we will use regex to remove numbers from rows
            row = re.sub(pattern, '' , row.text)
            
            row = re.sub(pattern2, '', row)

            print(row)

            array.append(row)

            # Remove duplicate from array
            array = list(dict.fromkeys(array))

    # Store every collection in a contenaire     
    list_.append(array)
# Out:
# https://www.ver-taal.com/voc_casa.htm
# Las partes de la casa
# Las partes de la casa
# Algunos muebles
# En la mesa
# En el dormitorio
# En el cuarto de baño
# En la cocina
# En el salón-comedor
# En el despacho
# En el despacho
# En el despacho
# El ordenador
# La puerta
# Suelos y paredes
# La electricidad
# Utensilios de cocina
# Electrodomésticos
# Electrodomésticos
# En el jardín
# El exterior de la casa
# Utensilios de limpieza
# Tareas domésticas
# https://www.ver-taal.com/voc_cuerpo.htm
# Las partes del cuerpo
# Las partes del cuerpo
# Las partes del cuerpo
# Las partes del cuerpo
# Las partes del cuerpo
# La cabeza
# La cabeza
# La cabeza
# La mano y el pie
# Los órganos
# Los huesos
# Los dientes
# Los fluidos corporales
# Manchas de la piel y problemas cutáneos
# Sensaciones corporales
# Posturas corporales
# Descripción de una persona
# Descripción de una persona
# Descripción de una persona
# El pelo
# El pelo
# La higiene
# La higiene
# La higiene
# Belleza y maquillaje
# Los tipos de medicamentos
# Los tipos de medicamentos
# Los tipos de medicamentos
# Material médico pequeño
# Material médico grande
# https://www.ver-taal.com/voc_animales.htm
# Animales domésticos
# Animales domésticos
# Animales domésticos
# Crías de animales
# Mamíferos españoles
# Insectos y otros pequeños animales
# Pájaros españoles
# Pájaros españoles
# Reptiles y anfibios
# Animales africanos
# Animales americanos
# Animales de los mares
# Insectos y otros pequeños animales
# Plagas y parásitos
# Partes del cuerpo
# Partes del cuerpo
# Partes del cuerpo
# https://www.ver-taal.com/voc_comida.htm
# La fruta
# La fruta
# La fruta
# La fruta
# Frutas tropicales
# Las hortalizas
# Las hortalizas
# Las hortalizas
# Las hortalizas
# Los productos lácteos
# Los huevos
# Cosas dulces
# Condimentos
# El pescado
# El pescado
# Los mariscos
# Los mariscos
# La carne
# Embutidos y fiambres
# Pan y cereales
# La bebida
# https://www.ver-taal.com/voc_ropa.htm
#  La ropa
#  La ropa
#  La ropa
#  La ropa
#  La ropa interior
#  El calzado
# Detalles de prendas de vestir
# Los complementos
# Telas y tejidos
# Hacer y reparar prendas
# https://www.ver-taal.com/voc_familia.htm
# Vocabulario de base
# Vocabulario de base
# Vocabulario de base
# Vocabulario de base
# Vocabulario completo
# Vocabulario completo
# Vocabulario completo
# El bebé
# El bebé
# El bebé
# https://www.ver-taal.com/voc_transporte.htm
# Los medios de transporte
# Los medios de transporte
# Barcos
# Partes del barco
# La bicicleta
# La bicicleta
# El coche
# El coche
# El coche
# La autopista
# Calles y carreteras
# https://www.ver-taal.com/voc_ocio.htm
# Actividades de ocio
# Actividades de ocio
# Actividades de ocio
# Actividades de ocio
# Actividades de ocio
# Juegos
# Las cartas
# El ajedrez
# Juegos infantiles
# Objetos de colección
# Objetos de colección
# Montar a caballo
# La decoración navideña
# La decoración navideña
# La decoración navideña
# Acampar - herramientas
# Acampar - dormir
# Atletismo
# Atletismo
# Atletismo
# Deportes de pelota
# Deportes acuáticos
# Deportes de nieve
# Otros deportes
# Instrumentos de viento
# Instrumentos de viento
# Instrumentos de viento
# Instrumentos de cuerda
# Instrumentos de tecla
# Instrumentos de percusión
# Otros instrumentos
# https://www.ver-taal.com/voc_trabajo.htm
# Profesiones salud, servicios públicos
# Profesiones salud, servicios públicos
# Profesiones salud, servicios públicos
# Profesiones construcción
# Profesiones alimentación
# Profesiones hotel, viajes, transporte
# Profesiones belleza, moda, tiendas
# Profesiones justicia, cultura, prensa
# Herramientas
# Herramientas
# Herramientas
# Herramientas
# Herramientas
# Herramientas de jardín
# Máquinas pesadas (construcción)
# https://www.ver-taal.com/voc_flora.htm
# Partes del árbol
# Partes del árbol
# Partes de la flor
# Flores ornamentales
# Plantas silvestres
# Árboles comunes
# https://www.ver-taal.com/voc_mundo.htm
# Países de Europa: presentación con audio
# Países de Europa: presentación con audio
# Países de Europa: presentación con audio
# Países de Europa: ejercicio de rellenar huecos
# Países de África: presentación con audio
# Países de África: ejercicio de rellenar huecos
# Países de Asia: presentación con audio
# Países de Asia: ejercicio de rellenar huecos
# Los nombres de los países: un concurso
# Los nombres de los países: un concurso
# Los gentilicios
# Los gentilicios
# Los paisajes: el agua
# Los paisajes: el agua
# Los paisajes: el agua
# Los paisajes: el monte
# El universo
# El tiempo (meteorológico)
# El tiempo (meteorológico)
# El tiempo: combinaciones de palabras
# El tiempo: buscar el intruso
# El tiempo: crucigrama
# El agua: crucigrama
# El agua: verbos
# Ríos europeos
# Los nombres geográficos
# Sinónimos: sustantivos
# Sinónimos: sustantivos
# Sinónimos: sustantivos
# Sinónimos: verbos
# Cambios en el clima
# https://www.ver-taal.com/voc_ciudad.htm
# Tiendas
# Tiendas
# Servicios y edificios públicos
# Servicios y edificios públicos
# Servicios y edificios públicos
# La iglesia
# El puerto
# El aeropuerto
# En el avión
# https://www.ver-taal.com/voc_formas.htm
# Los colores
# Los colores
# Numerales:-0
# Numerales:1 -0
# Numerales:0 -9
# Numerales:0 -9
# Numerales:0 -00
# Numerales:00 -99
# Numerales:00 -000
# Figuras y formas
# Cuerpos geométricos

# %%
df = pd.DataFrame(list_)

# %%
df
# Out:
#                                           0   \
# 0                      Las partes de la casa
# 1                      Las partes del cuerpo
# 2                       Animales domésticos
# 3                                  La fruta
# 4                                   La ropa
# 5                        Vocabulario de base
# 6                  Los medios de transporte
# 7                       Actividades de ocio
# 8      Profesiones salud, servicios públicos
# 9                           Partes del árbol
# 10  Países de Europa: presentación con audio
# 11                                   Tiendas
# 12                               Los colores
#
#                                                 1   \
# 0                                  Algunos muebles
# 1                                        La cabeza
# 2                                Crías de animales
# 3                                Frutas tropicales
# 4                                 La ropa interior
# 5                             Vocabulario completo
# 6                                           Barcos
# 7                                           Juegos
# 8                         Profesiones construcción
# 9                                Partes de la flor
# 10  Países de Europa: ejercicio de rellenar huecos
# 11                 Servicios y edificios públicos
# 12                                    Numerales:-0
#
#                                           2   \
# 0                                 En la mesa
# 1                           La mano y el pie
# 2                        Mamíferos españoles
# 3                            Las hortalizas
# 4                                 El calzado
# 5                                    El bebé
# 6                           Partes del barco
# 7                                 Las cartas
# 8                   Profesiones alimentación
# 9                        Flores ornamentales
# 10  Países de África: presentación con audio
# 11                                La iglesia
# 12                            Numerales:1 -0
#
#                                                 3   \
# 0                                 En el dormitorio
# 1                                      Los órganos
# 2              Insectos y otros pequeños animales
# 3                            Los productos lácteos
# 4                    Detalles de prendas de vestir
# 5                                             None
# 6                                    La bicicleta
# 7                                       El ajedrez
# 8            Profesiones hotel, viajes, transporte
# 9                               Plantas silvestres
# 10  Países de África: ejercicio de rellenar huecos
# 11                                       El puerto
# 12                                  Numerales:0 -9
#
#                                         4   \
# 0                     En el cuarto de baño
# 1                               Los huesos
# 2                       Pájaros españoles
# 3                               Los huevos
# 4                         Los complementos
# 5                                     None
# 6                                El coche
# 7                        Juegos infantiles
# 8       Profesiones belleza, moda, tiendas
# 9                         Árboles comunes
# 10  Países de Asia: presentación con audio
# 11                           El aeropuerto
# 12                         Numerales:0 -00
#
#                                               5   \
# 0                                   En la cocina
# 1                                    Los dientes
# 2                            Reptiles y anfibios
# 3                                   Cosas dulces
# 4                                Telas y tejidos
# 5                                           None
# 6                                   La autopista
# 7                          Objetos de colección
# 8          Profesiones justicia, cultura, prensa
# 9                                           None
# 10  Países de Asia: ejercicio de rellenar huecos
# 11                                   En el avión
# 12                              Numerales:00 -99
#
#                                          6   \
# 0                       En el salón-comedor
# 1                    Los fluidos corporales
# 2                        Animales africanos
# 3                               Condimentos
# 4                   Hacer y reparar prendas
# 5                                      None
# 6                       Calles y carreteras
# 7                          Montar a caballo
# 8                              Herramientas
# 9                                      None
# 10  Los nombres de los países: un concurso
# 11                                     None
# 12                        Numerales:00 -000
#
#                                          7                                8   \
# 0                           En el despacho                      El ordenador
# 1   Manchas de la piel y problemas cutáneos           Sensaciones corporales
# 2                       Animales americanos            Animales de los mares
# 3                               El pescado                     Los mariscos
# 4                                      None                             None
# 5                                      None                             None
# 6                                      None                             None
# 7                    La decoración navideña           Acampar - herramientas
# 8                    Herramientas de jardín  Máquinas pesadas (construcción)
# 9                                      None                             None
# 10                         Los gentilicios             Los paisajes: el agua
# 11                                     None                             None
# 12                         Figuras y formas              Cuerpos geométricos
#
#                         9   ...                                    12  \
# 0                La puerta  ...                  Utensilios de cocina
# 1      Posturas corporales  ...                            La higiene
# 2       Plagas y parásitos  ...                                  None
# 3                 La carne  ...                             La bebida
# 4                     None  ...                                  None
# 5                     None  ...                                  None
# 6                     None  ...                                  None
# 7         Acampar - dormir  ...                    Deportes acuáticos
# 8                     None  ...                                  None
# 9                     None  ...                                  None
# 10  Los paisajes: el monte  ...  El tiempo: combinaciones de palabras
# 11                    None  ...                                  None
# 12                    None  ...                                  None
#
#                               13                         14  \
# 0             Electrodomésticos                En el jardín
# 1           Belleza y maquillaje  Los tipos de medicamentos
# 2                           None                       None
# 3                           None                       None
# 4                           None                       None
# 5                           None                       None
# 6                           None                       None
# 7              Deportes de nieve             Otros deportes
# 8                           None                       None
# 9                           None                       None
# 10  El tiempo: buscar el intruso      El tiempo: crucigrama
# 11                          None                       None
# 12                          None                       None
#
#                          15                      16                     17  \
# 0    El exterior de la casa  Utensilios de limpieza      Tareas domésticas
# 1   Material médico pequeño  Material médico grande                   None
# 2                      None                    None                   None
# 3                      None                    None                   None
# 4                      None                    None                   None
# 5                      None                    None                   None
# 6                      None                    None                   None
# 7    Instrumentos de viento  Instrumentos de cuerda  Instrumentos de tecla
# 8                      None                    None                   None
# 9                      None                    None                   None
# 10      El agua: crucigrama         El agua: verbos          Ríos europeos
# 11                     None                    None                   None
# 12                     None                    None                   None
#
#                            18                      19                 20  \
# 0                        None                    None               None
# 1                        None                    None               None
# 2                        None                    None               None
# 3                        None                    None               None
# 4                        None                    None               None
# 5                        None                    None               None
# 6                        None                    None               None
# 7   Instrumentos de percusión      Otros instrumentos               None
# 8                        None                    None               None
# 9                        None                    None               None
# 10    Los nombres geográficos  Sinónimos: sustantivos  Sinónimos: verbos
# 11                       None                    None               None
# 12                       None                    None               None
#
#                      21
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# 5                  None
# 6                  None
# 7                  None
# 8                  None
# 9                  None
# 10  Cambios en el clima
# 11                 None
# 12                 None
#
# [13 rows x 22 columns]

# %%
# add headers to the columns
df.index = [headers_contenaire]

# %%
# rename headers of table  
df.columns =  ['Palabra' + str(i) for i in range(1, 23)]

# %%
df.head(2)
# Out:
#                                    Palabra1         Palabra2  \
# La casa               Las partes de la casa  Algunos muebles
# El cuerpo y la salud  Las partes del cuerpo        La cabeza
#
#                               Palabra3          Palabra4  \
# La casa                     En la mesa  En el dormitorio
# El cuerpo y la salud  La mano y el pie       Los órganos
#
#                                   Palabra5      Palabra6  \
# La casa               En el cuarto de baño  En la cocina
# El cuerpo y la salud            Los huesos   Los dientes
#
#                                     Palabra7  \
# La casa                  En el salón-comedor
# El cuerpo y la salud  Los fluidos corporales
#
#                                                      Palabra8  \
# La casa                                       En el despacho
# El cuerpo y la salud  Manchas de la piel y problemas cutáneos
#
#                                     Palabra9            Palabra10  ...  \
# La casa                         El ordenador            La puerta  ...
# El cuerpo y la salud  Sensaciones corporales  Posturas corporales  ...
#
#                                  Palabra13             Palabra14  \
# La casa               Utensilios de cocina    Electrodomésticos
# El cuerpo y la salud            La higiene  Belleza y maquillaje
#
#                                       Palabra15                Palabra16  \
# La casa                            En el jardín   El exterior de la casa
# El cuerpo y la salud  Los tipos de medicamentos  Material médico pequeño
#
#                                    Palabra17          Palabra18 Palabra19  \
# La casa               Utensilios de limpieza  Tareas domésticas      None
# El cuerpo y la salud  Material médico grande               None      None
#
#                      Palabra20 Palabra21 Palabra22
# La casa                   None      None      None
# El cuerpo y la salud      None      None      None
#
# [2 rows x 22 columns]

# %%
to_csv = df.to_csv('Introduccion.csv')

# %%
df
# Out:
#                                                                        Palabra1  \
# La casa                                                   Las partes de la casa
# El cuerpo y la salud                                      Las partes del cuerpo
# Los animales                                               Animales domésticos
# La comida                                                             La fruta
# La ropa                                                                La ropa
# La familia                                                  Vocabulario de base
# El transporte                                         Los medios de transporte
# El ocio                                                    Actividades de ocio
# El trabajo                                Profesiones salud, servicios públicos
# El mundo vegetal                                               Partes del árbol
# El Mundo                               Países de Europa: presentación con audio
# La ciudad                                                               Tiendas
# Los colores, los números y las formas                               Los colores
#
#                                                                              Palabra2  \
# La casa                                                               Algunos muebles
# El cuerpo y la salud                                                        La cabeza
# Los animales                                                        Crías de animales
# La comida                                                           Frutas tropicales
# La ropa                                                              La ropa interior
# La familia                                                       Vocabulario completo
# El transporte                                                                  Barcos
# El ocio                                                                        Juegos
# El trabajo                                                   Profesiones construcción
# El mundo vegetal                                                    Partes de la flor
# El Mundo                               Países de Europa: ejercicio de rellenar huecos
# La ciudad                                             Servicios y edificios públicos
# Los colores, los números y las formas                                    Numerales:-0
#
#                                                                        Palabra3  \
# La casa                                                              En la mesa
# El cuerpo y la salud                                           La mano y el pie
# Los animales                                                Mamíferos españoles
# La comida                                                       Las hortalizas
# La ropa                                                              El calzado
# La familia                                                              El bebé
# El transporte                                                  Partes del barco
# El ocio                                                              Las cartas
# El trabajo                                             Profesiones alimentación
# El mundo vegetal                                            Flores ornamentales
# El Mundo                               Países de África: presentación con audio
# La ciudad                                                            La iglesia
# Los colores, los números y las formas                            Numerales:1 -0
#
#                                                                              Palabra4  \
# La casa                                                              En el dormitorio
# El cuerpo y la salud                                                      Los órganos
# Los animales                                      Insectos y otros pequeños animales
# La comida                                                       Los productos lácteos
# La ropa                                                 Detalles de prendas de vestir
# La familia                                                                       None
# El transporte                                                           La bicicleta
# El ocio                                                                    El ajedrez
# El trabajo                                      Profesiones hotel, viajes, transporte
# El mundo vegetal                                                   Plantas silvestres
# El Mundo                               Países de África: ejercicio de rellenar huecos
# La ciudad                                                                   El puerto
# Los colores, los números y las formas                                  Numerales:0 -9
#
#                                                                      Palabra5  \
# La casa                                                  En el cuarto de baño
# El cuerpo y la salud                                               Los huesos
# Los animales                                               Pájaros españoles
# La comida                                                          Los huevos
# La ropa                                                      Los complementos
# La familia                                                               None
# El transporte                                                       El coche
# El ocio                                                     Juegos infantiles
# El trabajo                                 Profesiones belleza, moda, tiendas
# El mundo vegetal                                             Árboles comunes
# El Mundo                               Países de Asia: presentación con audio
# La ciudad                                                       El aeropuerto
# Los colores, los números y las formas                         Numerales:0 -00
#
#                                                                            Palabra6  \
# La casa                                                                En la cocina
# El cuerpo y la salud                                                    Los dientes
# Los animales                                                    Reptiles y anfibios
# La comida                                                              Cosas dulces
# La ropa                                                             Telas y tejidos
# La familia                                                                     None
# El transporte                                                          La autopista
# El ocio                                                       Objetos de colección
# El trabajo                                    Profesiones justicia, cultura, prensa
# El mundo vegetal                                                               None
# El Mundo                               Países de Asia: ejercicio de rellenar huecos
# La ciudad                                                               En el avión
# Los colores, los números y las formas                              Numerales:00 -99
#
#                                                                       Palabra7  \
# La casa                                                    En el salón-comedor
# El cuerpo y la salud                                    Los fluidos corporales
# Los animales                                                Animales africanos
# La comida                                                          Condimentos
# La ropa                                                Hacer y reparar prendas
# La familia                                                                None
# El transporte                                              Calles y carreteras
# El ocio                                                       Montar a caballo
# El trabajo                                                        Herramientas
# El mundo vegetal                                                          None
# El Mundo                               Los nombres de los países: un concurso
# La ciudad                                                                 None
# Los colores, los números y las formas                        Numerales:00 -000
#
#                                                                       Palabra8  \
# La casa                                                        En el despacho
# El cuerpo y la salud                   Manchas de la piel y problemas cutáneos
# Los animales                                               Animales americanos
# La comida                                                          El pescado
# La ropa                                                                   None
# La familia                                                                None
# El transporte                                                             None
# El ocio                                                 La decoración navideña
# El trabajo                                              Herramientas de jardín
# El mundo vegetal                                                          None
# El Mundo                                                      Los gentilicios
# La ciudad                                                                 None
# Los colores, los números y las formas                         Figuras y formas
#
#                                                               Palabra9  \
# La casa                                                   El ordenador
# El cuerpo y la salud                            Sensaciones corporales
# Los animales                                     Animales de los mares
# La comida                                                Los mariscos
# La ropa                                                           None
# La familia                                                        None
# El transporte                                                     None
# El ocio                                         Acampar - herramientas
# El trabajo                             Máquinas pesadas (construcción)
# El mundo vegetal                                                  None
# El Mundo                                         Los paisajes: el agua
# La ciudad                                                         None
# Los colores, los números y las formas              Cuerpos geométricos
#
#                                                     Palabra10  ...  \
# La casa                                             La puerta  ...
# El cuerpo y la salud                      Posturas corporales  ...
# Los animales                               Plagas y parásitos  ...
# La comida                                            La carne  ...
# La ropa                                                  None  ...
# La familia                                               None  ...
# El transporte                                            None  ...
# El ocio                                      Acampar - dormir  ...
# El trabajo                                               None  ...
# El mundo vegetal                                         None  ...
# El Mundo                               Los paisajes: el monte  ...
# La ciudad                                                None  ...
# Los colores, los números y las formas                    None  ...
#
#                                                                   Palabra13  \
# La casa                                                Utensilios de cocina
# El cuerpo y la salud                                             La higiene
# Los animales                                                           None
# La comida                                                         La bebida
# La ropa                                                                None
# La familia                                                             None
# El transporte                                                          None
# El ocio                                                  Deportes acuáticos
# El trabajo                                                             None
# El mundo vegetal                                                       None
# El Mundo                               El tiempo: combinaciones de palabras
# La ciudad                                                              None
# Los colores, los números y las formas                                  None
#
#                                                           Palabra14  \
# La casa                                          Electrodomésticos
# El cuerpo y la salud                           Belleza y maquillaje
# Los animales                                                   None
# La comida                                                      None
# La ropa                                                        None
# La familia                                                     None
# El transporte                                                  None
# El ocio                                           Deportes de nieve
# El trabajo                                                     None
# El mundo vegetal                                               None
# El Mundo                               El tiempo: buscar el intruso
# La ciudad                                                      None
# Los colores, los números y las formas                          None
#
#                                                        Palabra15  \
# La casa                                             En el jardín
# El cuerpo y la salud                   Los tipos de medicamentos
# Los animales                                                None
# La comida                                                   None
# La ropa                                                     None
# La familia                                                  None
# El transporte                                               None
# El ocio                                           Otros deportes
# El trabajo                                                  None
# El mundo vegetal                                            None
# El Mundo                                   El tiempo: crucigrama
# La ciudad                                                   None
# Los colores, los números y las formas                       None
#
#                                                      Palabra16  \
# La casa                                 El exterior de la casa
# El cuerpo y la salud                   Material médico pequeño
# Los animales                                              None
# La comida                                                 None
# La ropa                                                   None
# La familia                                                None
# El transporte                                             None
# El ocio                                 Instrumentos de viento
# El trabajo                                                None
# El mundo vegetal                                          None
# El Mundo                                   El agua: crucigrama
# La ciudad                                                 None
# Los colores, los números y las formas                     None
#
#                                                     Palabra17  \
# La casa                                Utensilios de limpieza
# El cuerpo y la salud                   Material médico grande
# Los animales                                             None
# La comida                                                None
# La ropa                                                  None
# La familia                                               None
# El transporte                                            None
# El ocio                                Instrumentos de cuerda
# El trabajo                                               None
# El mundo vegetal                                         None
# El Mundo                                      El agua: verbos
# La ciudad                                                None
# Los colores, los números y las formas                    None
#
#                                                    Palabra18  \
# La casa                                    Tareas domésticas
# El cuerpo y la salud                                    None
# Los animales                                            None
# La comida                                               None
# La ropa                                                 None
# La familia                                              None
# El transporte                                           None
# El ocio                                Instrumentos de tecla
# El trabajo                                              None
# El mundo vegetal                                        None
# El Mundo                                       Ríos europeos
# La ciudad                                               None
# Los colores, los números y las formas                   None
#
#                                                        Palabra19  \
# La casa                                                     None
# El cuerpo y la salud                                        None
# Los animales                                                None
# La comida                                                   None
# La ropa                                                     None
# La familia                                                  None
# El transporte                                               None
# El ocio                                Instrumentos de percusión
# El trabajo                                                  None
# El mundo vegetal                                            None
# El Mundo                                 Los nombres geográficos
# La ciudad                                                   None
# Los colores, los números y las formas                       None
#
#                                                     Palabra20  \
# La casa                                                  None
# El cuerpo y la salud                                     None
# Los animales                                             None
# La comida                                                None
# La ropa                                                  None
# La familia                                               None
# El transporte                                            None
# El ocio                                    Otros instrumentos
# El trabajo                                               None
# El mundo vegetal                                         None
# El Mundo                               Sinónimos: sustantivos
# La ciudad                                                None
# Los colores, los números y las formas                    None
#
#                                                Palabra21            Palabra22
# La casa                                             None                 None
# El cuerpo y la salud                                None                 None
# Los animales                                        None                 None
# La comida                                           None                 None
# La ropa                                             None                 None
# La familia                                          None                 None
# El transporte                                       None                 None
# El ocio                                             None                 None
# El trabajo                                          None                 None
# El mundo vegetal                                    None                 None
# El Mundo                               Sinónimos: verbos  Cambios en el clima
# La ciudad                                           None                 None
# Los colores, los números y las formas               None                 None
#
# [13 rows x 22 columns]
