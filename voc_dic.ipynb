# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
url = 'https://www.ver-taal.com/vocabulario.htm'

# %%
# accessing the html content form webpage
response = requests.get(url)

# parsing the html content
soup = BeautifulSoup(response.content, 'html')

# get the title 
title = soup.title.text + '.csv'

title
# Out:
# 'Ejercicios de vocabulario.csv'

# %%
# extract the element from list that we will include it as headers

headers_contenaire =[] # here we where store our hearders

# this tag contains the list of elements
headers = soup.select_one('ul', attri={'class':'nolist'})

type(headers)
# Out:
# bs4.element.Tag

# %%
# Iterate all row in list in html
for row in headers:
    
    # romove the element which
    if row != '\n':
    
        headers_contenaire.append(row.text) # add each row to the list

print(headers_contenaire)
# Out:
# ['La casa\nEl cuerpo y la salud\nLos animales\nLa comida\nLa ropa\nLa familia\nEl transporte\nEl ocio\nEl trabajo\nEl mundo vegetal\nEl Mundo\nLa ciudad\nLos colores, los números y las formas\n']

# %%
# Remove Empty, underline elements
headers_contenaire = list(filter(None, headers_contenaire[0].split('\n')))

headers_contenaire
# Out:
# ['La casa',
#  'El cuerpo y la salud',
#  'Los animales',
#  'La comida',
#  'La ropa',
#  'La familia',
#  'El transporte',
#  'El ocio',
#  'El trabajo',
#  'El mundo vegetal',
#  'El Mundo',
#  'La ciudad',
#  'Los colores, los números y las formas']

# %%
# Now after we obtain the headers we will dive deeper into each element using it href to get it data

a = headers.find_all('a')

list_ = []
for href in a:
    array = []

    # Extract all links of rows
    url = 'https://www.ver-taal.com/' + href.get('href')
    
    print(url)

    # parsing each url using BeautifulSoup model
    url = requests.get(url)


    soup_2 = BeautifulSoup(url.content, 'html')

    table = soup_2.table

 
    for row in table.find_all('tr'):
        
        row = row.find('a')

         # add each collection to an array
        if row is not None:
            
            # this pattern of elinated elements
            pattern = r'\W\d\W'

            pattern2 = r' \d'
            
            # we will use regex to remove numbers from rows
            row = re.sub(pattern, '' , row.text)
            
            row = re.sub(pattern2, '', row)

            print(row)

            array.append(row)

            # Remove duplicate from array
            array = list(dict.fromkeys(array))

    # Store every collection in a contenaire     
    list_.append(array)
# Out:
# https://www.ver-taal.com/voc_casa.htm
# Las partes de la casa
# Las partes de la casa
# Algunos muebles
# En la mesa
# En el dormitorio
# En el cuarto de baño
# En la cocina
# En el salón-comedor
# En el despacho
# En el despacho
# En el despacho
# El ordenador
# La puerta
# Suelos y paredes
# La electricidad
# Utensilios de cocina
# Electrodomésticos
# Electrodomésticos
# En el jardín
# El exterior de la casa
# Utensilios de limpieza
# Tareas domésticas
# https://www.ver-taal.com/voc_cuerpo.htm
# Las partes del cuerpo
# Las partes del cuerpo
# Las partes del cuerpo
# Las partes del cuerpo
# Las partes del cuerpo
# La cabeza
# La cabeza
# La cabeza
# La mano y el pie
# Los órganos
# Los huesos
# Los dientes
# Los fluidos corporales
# Manchas de la piel y problemas cutáneos
# Sensaciones corporales
# Posturas corporales
# Descripción de una persona
# Descripción de una persona
# Descripción de una persona
# El pelo
# El pelo
# La higiene
# La higiene
# La higiene
# Belleza y maquillaje
# Los tipos de medicamentos
# Los tipos de medicamentos
# Los tipos de medicamentos
# Material médico pequeño
# Material médico grande
# https://www.ver-taal.com/voc_animales.htm
# Animales domésticos
# Animales domésticos
# Animales domésticos
# Crías de animales
# Mamíferos españoles
# Insectos y otros pequeños animales
# Pájaros españoles
# Pájaros españoles
# Reptiles y anfibios
# Animales africanos
# Animales americanos
# Animales de los mares
# Insectos y otros pequeños animales
# Plagas y parásitos
# Partes del cuerpo
# Partes del cuerpo
# Partes del cuerpo
# https://www.ver-taal.com/voc_comida.htm
# La fruta
# La fruta
# La fruta
# La fruta
# Frutas tropicales
# Las hortalizas
# Las hortalizas
# Las hortalizas
# Las hortalizas
# Los productos lácteos
# Los huevos
# Cosas dulces
# Condimentos
# El pescado
# El pescado
# Los mariscos
# Los mariscos
# La carne
# Embutidos y fiambres
# Pan y cereales
# La bebida
# https://www.ver-taal.com/voc_ropa.htm
#  La ropa
#  La ropa
#  La ropa
#  La ropa
#  La ropa interior
#  El calzado
# Detalles de prendas de vestir
# Los complementos
# Telas y tejidos
# Hacer y reparar prendas
# https://www.ver-taal.com/voc_familia.htm
# Vocabulario de base
# Vocabulario de base
# Vocabulario de base
# Vocabulario de base
# Vocabulario completo
# Vocabulario completo
# Vocabulario completo
# El bebé
# El bebé
# El bebé
# https://www.ver-taal.com/voc_transporte.htm
# Los medios de transporte
# Los medios de transporte
# Barcos
# Partes del barco
# La bicicleta
# La bicicleta
# El coche
# El coche
# El coche
# La autopista
# Calles y carreteras
# https://www.ver-taal.com/voc_ocio.htm
# Actividades de ocio
# Actividades de ocio
# Actividades de ocio
# Actividades de ocio
# Actividades de ocio
# Juegos
# Las cartas
# El ajedrez
# Juegos infantiles
# Objetos de colección
# Objetos de colección
# Montar a caballo
# La decoración navideña
# La decoración navideña
# La decoración navideña
# Acampar - herramientas
# Acampar - dormir
# Atletismo
# Atletismo
# Atletismo
# Deportes de pelota
# Deportes acuáticos
# Deportes de nieve
# Otros deportes
# Instrumentos de viento
# Instrumentos de viento
# Instrumentos de viento
# Instrumentos de cuerda
# Instrumentos de tecla
# Instrumentos de percusión
# Otros instrumentos
# https://www.ver-taal.com/voc_trabajo.htm
# Profesiones salud, servicios públicos
# Profesiones salud, servicios públicos
# Profesiones salud, servicios públicos
# Profesiones construcción
# Profesiones alimentación
# Profesiones hotel, viajes, transporte
# Profesiones belleza, moda, tiendas
# Profesiones justicia, cultura, prensa
# Herramientas
# Herramientas
# Herramientas
# Herramientas
# Herramientas
# Herramientas de jardín
# Máquinas pesadas (construcción)
# https://www.ver-taal.com/voc_flora.htm
# Partes del árbol
# Partes del árbol
# Partes de la flor
# Flores ornamentales
# Plantas silvestres
# Árboles comunes
# https://www.ver-taal.com/voc_mundo.htm
# Países de Europa: presentación con audio
# Países de Europa: presentación con audio
# Países de Europa: presentación con audio
# Países de Europa: ejercicio de rellenar huecos
# Países de África: presentación con audio
# Países de África: ejercicio de rellenar huecos
# Países de Asia: presentación con audio
# Países de Asia: ejercicio de rellenar huecos
# Los nombres de los países: un concurso
# Los nombres de los países: un concurso
# Los gentilicios
# Los gentilicios
# Los paisajes: el agua
# Los paisajes: el agua
# Los paisajes: el agua
# Los paisajes: el monte
# El universo
# El tiempo (meteorológico)
# El tiempo (meteorológico)
# El tiempo: combinaciones de palabras
# El tiempo: buscar el intruso
# El tiempo: crucigrama
# El agua: crucigrama
# El agua: verbos
# Ríos europeos
# Los nombres geográficos
# Sinónimos: sustantivos
# Sinónimos: sustantivos
# Sinónimos: sustantivos
# Sinónimos: verbos
# Cambios en el clima
# https://www.ver-taal.com/voc_ciudad.htm
# Tiendas
# Tiendas
# Servicios y edificios públicos
# Servicios y edificios públicos
# Servicios y edificios públicos
# La iglesia
# El puerto
# El aeropuerto
# En el avión
# https://www.ver-taal.com/voc_formas.htm
# Los colores
# Los colores
# Numerales:-0
# Numerales:1 -0
# Numerales:0 -9
# Numerales:0 -9
# Numerales:0 -00
# Numerales:00 -99
# Numerales:00 -000
# Figuras y formas
# Cuerpos geométricos

# %%
df = pd.DataFrame(list_)

# %%
df
# Out:
#                                           0   \
# 0                      Las partes de la casa
# 1                      Las partes del cuerpo
# 2                       Animales domésticos
# 3                                  La fruta
# 4                                   La ropa
# 5                        Vocabulario de base
# 6                  Los medios de transporte
# 7                       Actividades de ocio
# 8      Profesiones salud, servicios públicos
# 9                           Partes del árbol
# 10  Países de Europa: presentación con audio
# 11                                   Tiendas
# 12                               Los colores
#
#                                                 1   \
# 0                                  Algunos muebles
# 1                                        La cabeza
# 2                                Crías de animales
# 3                                Frutas tropicales
# 4                                 La ropa interior
# 5                             Vocabulario completo
# 6                                           Barcos
# 7                                           Juegos
# 8                         Profesiones construcción
# 9                                Partes de la flor
# 10  Países de Europa: ejercicio de rellenar huecos
# 11                 Servicios y edificios públicos
# 12                                    Numerales:-0
#
#                                           2   \
# 0                                 En la mesa
# 1                           La mano y el pie
# 2                        Mamíferos españoles
# 3                            Las hortalizas
# 4                                 El calzado
# 5                                    El bebé
# 6                           Partes del barco
# 7                                 Las cartas
# 8                   Profesiones alimentación
# 9                        Flores ornamentales
# 10  Países de África: presentación con audio
# 11                                La iglesia
# 12                            Numerales:1 -0
#
#                                                 3   \
# 0                                 En el dormitorio
# 1                                      Los órganos
# 2              Insectos y otros pequeños animales
# 3                            Los productos lácteos
# 4                    Detalles de prendas de vestir
# 5                                             None
# 6                                    La bicicleta
# 7                                       El ajedrez
# 8            Profesiones hotel, viajes, transporte
# 9                               Plantas silvestres
# 10  Países de África: ejercicio de rellenar huecos
# 11                                       El puerto
# 12                                  Numerales:0 -9
#
#                                         4   \
# 0                     En el cuarto de baño
# 1                               Los huesos
# 2                       Pájaros españoles
# 3                               Los huevos
# 4                         Los complementos
# 5                                     None
# 6                                El coche
# 7                        Juegos infantiles
# 8       Profesiones belleza, moda, tiendas
# 9                         Árboles comunes
# 10  Países de Asia: presentación con audio
# 11                           El aeropuerto
# 12                         Numerales:0 -00
#
#                                               5   \
# 0                                   En la cocina
# 1                                    Los dientes
# 2                            Reptiles y anfibios
# 3                                   Cosas dulces
# 4                                Telas y tejidos
# 5                                           None
# 6                                   La autopista
# 7                          Objetos de colección
# 8          Profesiones justicia, cultura, prensa
# 9                                           None
# 10  Países de Asia: ejercicio de rellenar huecos
# 11                                   En el avión
# 12                              Numerales:00 -99
#
#                                          6   \
# 0                       En el salón-comedor
# 1                    Los fluidos corporales
# 2                        Animales africanos
# 3                               Condimentos
# 4                   Hacer y reparar prendas
# 5                                      None
# 6                       Calles y carreteras
# 7                          Montar a caballo
# 8                              Herramientas
# 9                                      None
# 10  Los nombres de los países: un concurso
# 11                                     None
# 12                        Numerales:00 -000
#
#                                          7                                8   \
# 0                           En el despacho                      El ordenador
# 1   Manchas de la piel y problemas cutáneos           Sensaciones corporales
# 2                       Animales americanos            Animales de los mares
# 3                               El pescado                     Los mariscos
# 4                                      None                             None
# 5                                      None                             None
# 6                                      None                             None
# 7                    La decoración navideña           Acampar - herramientas
# 8                    Herramientas de jardín  Máquinas pesadas (construcción)
# 9                                      None                             None
# 10                         Los gentilicios             Los paisajes: el agua
# 11                                     None                             None
# 12                         Figuras y formas              Cuerpos geométricos
#
#                         9   ...                                    12  \
# 0                La puerta  ...                  Utensilios de cocina
# 1      Posturas corporales  ...                            La higiene
# 2       Plagas y parásitos  ...                                  None
# 3                 La carne  ...                             La bebida
# 4                     None  ...                                  None
# 5                     None  ...                                  None
# 6                     None  ...                                  None
# 7         Acampar - dormir  ...                    Deportes acuáticos
# 8                     None  ...                                  None
# 9                     None  ...                                  None
# 10  Los paisajes: el monte  ...  El tiempo: combinaciones de palabras
# 11                    None  ...                                  None
# 12                    None  ...                                  None
#
#                               13                         14  \
# 0             Electrodomésticos                En el jardín
# 1           Belleza y maquillaje  Los tipos de medicamentos
# 2                           None                       None
# 3                           None                       None
# 4                           None                       None
# 5                           None                       None
# 6                           None                       None
# 7              Deportes de nieve             Otros deportes
# 8                           None                       None
# 9                           None                       None
# 10  El tiempo: buscar el intruso      El tiempo: crucigrama
# 11                          None                       None
# 12                          None                       None
#
#                          15                      16                     17  \
# 0    El exterior de la casa  Utensilios de limpieza      Tareas domésticas
# 1   Material médico pequeño  Material médico grande                   None
# 2                      None                    None                   None
# 3                      None                    None                   None
# 4                      None                    None                   None
# 5                      None                    None                   None
# 6                      None                    None                   None
# 7    Instrumentos de viento  Instrumentos de cuerda  Instrumentos de tecla
# 8                      None                    None                   None
# 9                      None                    None                   None
# 10      El agua: crucigrama         El agua: verbos          Ríos europeos
# 11                     None                    None                   None
# 12                     None                    None                   None
#
#                            18                      19                 20  \
# 0                        None                    None               None
# 1                        None                    None               None
# 2                        None                    None               None
# 3                        None                    None               None
# 4                        None                    None               None
# 5                        None                    None               None
# 6                        None                    None               None
# 7   Instrumentos de percusión      Otros instrumentos               None
# 8                        None                    None               None
# 9                        None                    None               None
# 10    Los nombres geográficos  Sinónimos: sustantivos  Sinónimos: verbos
# 11                       None                    None               None
# 12                       None                    None               None
#
#                      21
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# 5                  None
# 6                  None
# 7                  None
# 8                  None
# 9                  None
# 10  Cambios en el clima
# 11                 None
# 12                 None
#
# [13 rows x 22 columns]

# %%
# add headers to the columns
df.index = [headers_contenaire]

# %%
# rename headers of table  
df.columns =  ['Palabra' + str(i) for i in range(1, 23)]

# %%
df.head(2)
# Out:
#                                    Palabra1         Palabra2  \
# La casa               Las partes de la casa  Algunos muebles
# El cuerpo y la salud  Las partes del cuerpo        La cabeza
#
#                               Palabra3          Palabra4  \
# La casa                     En la mesa  En el dormitorio
# El cuerpo y la salud  La mano y el pie       Los órganos
#
#                                   Palabra5      Palabra6  \
# La casa               En el cuarto de baño  En la cocina
# El cuerpo y la salud            Los huesos   Los dientes
#
#                                     Palabra7  \
# La casa                  En el salón-comedor
# El cuerpo y la salud  Los fluidos corporales
#
#                                                      Palabra8  \
# La casa                                       En el despacho
# El cuerpo y la salud  Manchas de la piel y problemas cutáneos
#
#                                     Palabra9            Palabra10  ...  \
# La casa                         El ordenador            La puerta  ...
# El cuerpo y la salud  Sensaciones corporales  Posturas corporales  ...
#
#                                  Palabra13             Palabra14  \
# La casa               Utensilios de cocina    Electrodomésticos
# El cuerpo y la salud            La higiene  Belleza y maquillaje
#
#                                       Palabra15                Palabra16  \
# La casa                            En el jardín   El exterior de la casa
# El cuerpo y la salud  Los tipos de medicamentos  Material médico pequeño
#
#                                    Palabra17          Palabra18 Palabra19  \
# La casa               Utensilios de limpieza  Tareas domésticas      None
# El cuerpo y la salud  Material médico grande               None      None
#
#                      Palabra20 Palabra21 Palabra22
# La casa                   None      None      None
# El cuerpo y la salud      None      None      None
#
# [2 rows x 22 columns]

# %%
to_csv = df.to_csv('Introduccion.csv')

# %%
df
# Out:
#                    La casa                     El cuerpo y la salud  \
# 1    Las partes de la casa                    Las partes del cuerpo
# 2          Algunos muebles                                La cabeza
# 3               En la mesa                         La mano y el pie
# 4         En el dormitorio                              Los órganos
# 5     En el cuarto de baño                               Los huesos
# 6             En la cocina                              Los dientes
# 7      En el salón-comedor                   Los fluidos corporales
# 8          En el despacho   Manchas de la piel y problemas cutáneos
# 9             El ordenador                   Sensaciones corporales
# 10               La puerta                      Posturas corporales
# 11        Suelos y paredes               Descripción de una persona
# 12         La electricidad                                 El pelo
# 13    Utensilios de cocina                               La higiene
# 14      Electrodomésticos                      Belleza y maquillaje
# 15            En el jardín                Los tipos de medicamentos
# 16  El exterior de la casa                  Material médico pequeño
# 17  Utensilios de limpieza                   Material médico grande
# 18       Tareas domésticas                                     None
# 19                    None                                     None
# 20                    None                                     None
# 21                    None                                     None
# 22                    None                                     None
#
#                            Los animales              La comida  \
# 1                  Animales domésticos               La fruta
# 2                     Crías de animales      Frutas tropicales
# 3                   Mamíferos españoles        Las hortalizas
# 4   Insectos y otros pequeños animales   Los productos lácteos
# 5                    Pájaros españoles              Los huevos
# 6                   Reptiles y anfibios           Cosas dulces
# 7                    Animales africanos            Condimentos
# 8                   Animales americanos            El pescado
# 9                 Animales de los mares          Los mariscos
# 10                   Plagas y parásitos               La carne
# 11                   Partes del cuerpo    Embutidos y fiambres
# 12                                 None         Pan y cereales
# 13                                 None              La bebida
# 14                                 None                   None
# 15                                 None                   None
# 16                                 None                   None
# 17                                 None                   None
# 18                                 None                   None
# 19                                 None                   None
# 20                                 None                   None
# 21                                 None                   None
# 22                                 None                   None
#
#                           La ropa            La familia  \
# 1                        La ropa    Vocabulario de base
# 2                La ropa interior  Vocabulario completo
# 3                      El calzado               El bebé
# 4   Detalles de prendas de vestir                  None
# 5                Los complementos                  None
# 6                 Telas y tejidos                  None
# 7         Hacer y reparar prendas                  None
# 8                            None                  None
# 9                            None                  None
# 10                           None                  None
# 11                           None                  None
# 12                           None                  None
# 13                           None                  None
# 14                           None                  None
# 15                           None                  None
# 16                           None                  None
# 17                           None                  None
# 18                           None                  None
# 19                           None                  None
# 20                           None                  None
# 21                           None                  None
# 22                           None                  None
#
#                 El transporte                    El ocio  \
# 1   Los medios de transporte        Actividades de ocio
# 2                      Barcos                     Juegos
# 3            Partes del barco                 Las cartas
# 4               La bicicleta                  El ajedrez
# 5                   El coche           Juegos infantiles
# 6                La autopista      Objetos de colección
# 7         Calles y carreteras           Montar a caballo
# 8                        None     La decoración navideña
# 9                        None     Acampar - herramientas
# 10                       None           Acampar - dormir
# 11                       None                  Atletismo
# 12                       None         Deportes de pelota
# 13                       None         Deportes acuáticos
# 14                       None          Deportes de nieve
# 15                       None             Otros deportes
# 16                       None     Instrumentos de viento
# 17                       None     Instrumentos de cuerda
# 18                       None      Instrumentos de tecla
# 19                       None  Instrumentos de percusión
# 20                       None         Otros instrumentos
# 21                       None                       None
# 22                       None                       None
#
#                                El trabajo     El mundo vegetal  \
# 1   Profesiones salud, servicios públicos     Partes del árbol
# 2                Profesiones construcción    Partes de la flor
# 3                Profesiones alimentación  Flores ornamentales
# 4   Profesiones hotel, viajes, transporte   Plantas silvestres
# 5      Profesiones belleza, moda, tiendas     Árboles comunes
# 6   Profesiones justicia, cultura, prensa                 None
# 7                            Herramientas                 None
# 8                  Herramientas de jardín                 None
# 9         Máquinas pesadas (construcción)                 None
# 10                                   None                 None
# 11                                   None                 None
# 12                                   None                 None
# 13                                   None                 None
# 14                                   None                 None
# 15                                   None                 None
# 16                                   None                 None
# 17                                   None                 None
# 18                                   None                 None
# 19                                   None                 None
# 20                                   None                 None
# 21                                   None                 None
# 22                                   None                 None
#
#                                           El Mundo  \
# 1         Países de Europa: presentación con audio
# 2   Países de Europa: ejercicio de rellenar huecos
# 3         Países de África: presentación con audio
# 4   Países de África: ejercicio de rellenar huecos
# 5           Países de Asia: presentación con audio
# 6     Países de Asia: ejercicio de rellenar huecos
# 7          Los nombres de los países: un concurso
# 8                                 Los gentilicios
# 9                            Los paisajes: el agua
# 10                          Los paisajes: el monte
# 11                                     El universo
# 12                      El tiempo (meteorológico)
# 13            El tiempo: combinaciones de palabras
# 14                    El tiempo: buscar el intruso
# 15                           El tiempo: crucigrama
# 16                             El agua: crucigrama
# 17                                 El agua: verbos
# 18                                   Ríos europeos
# 19                         Los nombres geográficos
# 20                          Sinónimos: sustantivos
# 21                               Sinónimos: verbos
# 22                             Cambios en el clima
#
#                           La ciudad Los colores, los números y las formas
# 1                           Tiendas                           Los colores
# 2   Servicios y edificios públicos                           Numerales:-0
# 3                        La iglesia                        Numerales:1 -0
# 4                         El puerto                        Numerales:0 -9
# 5                     El aeropuerto                       Numerales:0 -00
# 6                       En el avión                      Numerales:00 -99
# 7                              None                     Numerales:00 -000
# 8                              None                      Figuras y formas
# 9                              None                   Cuerpos geométricos
# 10                             None                                  None
# 11                             None                                  None
# 12                             None                                  None
# 13                             None                                  None
# 14                             None                                  None
# 15                             None                                  None
# 16                             None                                  None
# 17                             None                                  None
# 18                             None                                  None
# 19                             None                                  None
# 20                             None                                  None
# 21                             None                                  None
# 22                             None                                  None
